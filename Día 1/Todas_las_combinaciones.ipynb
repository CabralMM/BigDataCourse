# %%
import pandas as pd
from itertools import product

a = ["IND-PAD",
"IND-GRA",
"IND-PER",
"DOB-PAD",
"DOB-GRA",
"DOB-PER",
"QUE-PAD",
"QUE-GRA",
"QUE-PER",
"KIN-PAD",
"KIN-GRA",
"KIN-PER",
"SUP-PAD",
"SUP-GRA",
"SUP-PER"]
b= ["ALE",
"ARI",
"NOV",
"VIC",
"WYN"]
c=["ALG",
"SDE",
"VLV",
"PLP",
"COU",
"PCL",
"SNT",
"JTR"]

combination = list(product(a,b,c))
print(combination)

for x in combination:
  print (x)
# Out:
# [('IND-PAD', 'ALE', 'ALG'), ('IND-PAD', 'ALE', 'SDE'), ('IND-PAD', 'ALE', 'VLV'), ('IND-PAD', 'ALE', 'PLP'), ('IND-PAD', 'ALE', 'COU'), ('IND-PAD', 'ALE', 'PCL'), ('IND-PAD', 'ALE', 'SNT'), ('IND-PAD', 'ALE', 'JTR'), ('IND-PAD', 'ARI', 'ALG'), ('IND-PAD', 'ARI', 'SDE'), ('IND-PAD', 'ARI', 'VLV'), ('IND-PAD', 'ARI', 'PLP'), ('IND-PAD', 'ARI', 'COU'), ('IND-PAD', 'ARI', 'PCL'), ('IND-PAD', 'ARI', 'SNT'), ('IND-PAD', 'ARI', 'JTR'), ('IND-PAD', 'NOV', 'ALG'), ('IND-PAD', 'NOV', 'SDE'), ('IND-PAD', 'NOV', 'VLV'), ('IND-PAD', 'NOV', 'PLP'), ('IND-PAD', 'NOV', 'COU'), ('IND-PAD', 'NOV', 'PCL'), ('IND-PAD', 'NOV', 'SNT'), ('IND-PAD', 'NOV', 'JTR'), ('IND-PAD', 'VIC', 'ALG'), ('IND-PAD', 'VIC', 'SDE'), ('IND-PAD', 'VIC', 'VLV'), ('IND-PAD', 'VIC', 'PLP'), ('IND-PAD', 'VIC', 'COU'), ('IND-PAD', 'VIC', 'PCL'), ('IND-PAD', 'VIC', 'SNT'), ('IND-PAD', 'VIC', 'JTR'), ('IND-PAD', 'WYN', 'ALG'), ('IND-PAD', 'WYN', 'SDE'), ('IND-PAD', 'WYN', 'VLV'), ('IND-PAD', 'WYN', 'PLP'), ('IND-PAD', 'WYN', 'COU')
# ...
