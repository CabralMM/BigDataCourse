# %%
# CREAR VARIABLES
# nombre_variable = valor
numero = 6
decimal = 6.2 # Esto es un float
texto = "Luis"
verdadero = True
falso = False

# %%
# USAR VARIABLES
print(numero)
print(texto)
# Out:
# 6
# Luis

# %%
# LISTA
lista = [1,2,3,"Hola",True]
lista[4] = 89
lista.append("Pepe")
lista
# Out:
# [1, 2, 3, 'Hola', 89, 'Pepe']

# %%
6 + 2 + 3.0
# Out:
# 11.0

# %%
str1 = 'Me gusta Python'
str1[3]
# Out:
# 'g'

# %%
str1 = ['Me', 'gusta', 'Python']
str1[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-81893f316800> in <cell line: 2>()
#       1 str1 = ['Me', 'gusta', 'Python']
# ----> 2 str1[3]
#
# IndexError: list index out of range

# %%
var1 = "hello"
var2 = "world"

# %%
var1 + " " + var2
# Out:
# 'hello world'

# %%
print(var1,var2)
# Out:
# hello world

# %%
"hello" + "world"
# Out:
# 'helloworld'

# %%
# , [] () ; fstring jerarquia lista

# %%
lista1 = [5,6,7]
lista2 = [1,2,3]

# %%
lista1 + lista2
# Out:
# [5, 6, 7, 1, 2, 3]

# %%
2 + 6 * 3
# Out:
# 20

# %%
# []
# ()
# {}

# %%
var = [1,2,3]

# %%
var[0]
# Out:
# 1

# %%
print("HOla")
# Out:
# HOla

# %%
a, b,c = 5 , 6, 9
b
# Out:
# 6

# %%
nombre = "Luis"
print("Hola " + nombre)
# Out:
# Hola Luis

# %%
print(f"Hola {nombre}")
# Out:
# Hola Luis

# %%
colores = ["red","orange","blue"]

# %%
colores.append("purple")
colores.append("yellow")
print(colores)
# Out:
# ['red', 'orange', 'blue', 'purple', 'yellow']

# %%
# FIFO, FIRST IN FIRST OUT

# %%
colores.insert(1,"grey")
colores
# Out:
# ['red', 'grey', 'orange', 'blue', 'purple', 'yellow']

# %%
# CONDICIONES

# %%
# OPERADORES 
# OPERADOR DE ASIGNACIÓN
# nombre_variable = valor
# OPERADORES ARITMÉTICOS
6 + 2
9 - 2
6 * 2
9 / 2
9 // 2
9 ** 2
9 % 2
# OPERADORES DE COMPARACIÓN
var1 = 9
var2 = "9"
var1 == var2 # True si son iguales, False si son distintas
10 != "10" # True si son distintas, False si son iguales
10 > 5 
10 >= 10
10 < 5
10 <= 5
1 in [2,3,1,4]
# OPERADORES LÓGICOS
and
or
not
# Out:
# True

# %%
nuestra_velocidad = 120
maxima_velocidad = 120

if nuestra_velocidad < maxima_velocidad:
  print("Todo OK")
elif nuestra_velocidad == maxima_velocidad:
  print("Deja de acelerar")
else:
  print("Multita")
# Out:
# Deja de acelerar

# %%
nuestra_velocidad = 110
maxima_velocidad = 120

if nuestra_velocidad < maxima_velocidad:
  print("Todo OK")
elif nuestra_velocidad == maxima_velocidad:
  print("Deja de acelerar")
else:
  print("Multita")
# Out:
# Todo OK
# Multita

# %%
if condicion:
  pass
elif condicion2:
  pass
elif condicion3:
  pass
else:
  pass

# %%
  # VARIABLES
  # CREAR VARIABLES
  numero = 6
  # USAR VARIABLES
  numero_nuevo = numero * 2
  numero_nuevo
# Out:
# 12

# %%
# TIPOS DE DATOS
6
-35
9.5
-1.0
"Hola"
'Hola'
"""Hola"""

True
False

# %%
# ESTRUCTURAS DE DATOS
# LISTAS
lista = ["red","orange","blue"]
# TUPLAS
tuplas = ("red","orange","blue")
# CONJUNTOS - SET
conjunto = {"red","orange","blue","orange"}
conjunto
# DICCIONARIOS
diccionario = {0:"red",1:"orange",2:"blue","Hola":564546}
agenda = {"Luis":6666666666,"Pepe":54565445654,"Julian":False}
agenda["Julian"]
# Out:
# False

# %%
lista = [1,2,3,4,2,4,2,4,3]

list(set(lista))
# Out:
# [1, 2, 3, 4]

# %%
# CONDICIONES
day = "Lunes"
if day == "Martes":
  print("Hay que crearse cuenta en Github")
if day == "Lunes":
  print("Aprendemos python")
# Out:
# Aprendemos python
